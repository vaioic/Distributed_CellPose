# %%
import numpy as np
import zarr
import scipy.ndimage
from cellpose.contrib import distributed_segmentation
from dask_image.ndmeasure._utils._label import _across_block_label_grouping
from cellpose.contrib.distributed_segmentation import distributed_eval

# %%
def fixed_block_face_adjacency_graph(faces, nlabels):
    """Fixed version that determines structure dimensionality from data"""
    nlabels = int(nlabels)
    all_mappings = []
    
    ndim = faces[0].ndim if len(faces) > 0 else 3
    structure = scipy.ndimage.generate_binary_structure(ndim, 1)
    
    for face in faces:
        sl0 = tuple(slice(0, 1) if d==2 else slice(None) for d in face.shape)
        sl1 = tuple(slice(1, 2) if d==2 else slice(None) for d in face.shape)
        a = distributed_segmentation.shrink_labels(face[sl0], 1.0)
        b = distributed_segmentation.shrink_labels(face[sl1], 1.0)
        face = np.concatenate((a, b), axis=np.argmin(a.shape))
        mapped = _across_block_label_grouping(face, structure)
        all_mappings.append(mapped)
    
    i, j = np.concatenate(all_mappings, axis=1)
    v = np.ones_like(i)
    return scipy.sparse.coo_matrix((v, (i, j)), shape=(nlabels+1, nlabels+1)).tocsr()

# ========== PATCH 2: Handle multi-channel process_block ==========
def fixed_process_block(
    block_index,
    crop,
    input_zarr,
    model_kwargs,
    eval_kwargs,
    blocksize,
    overlap,
    output_zarr,
    preprocessing_steps=[],
    worker_logs_directory=None,
    test_mode=False,
    channel_axis=None,
    output_shape=None,
):
    """Modified to handle multi-channel input with 2D output"""
    print('RUNNING BLOCK: ', block_index, '\tREGION: ', crop, flush=True)
    
    segmentation = distributed_segmentation.read_preprocess_and_segment(
        input_zarr, crop, preprocessing_steps, model_kwargs, eval_kwargs,
        worker_logs_directory,
    )
    
    # Strip channel dimension from crop for output (if needed)
    if channel_axis is not None and output_shape is not None:
        output_crop = list(crop)
        del output_crop[channel_axis]  # Remove channel dimension
        output_crop = tuple(output_crop)
        output_blocksize = list(blocksize)
        del output_blocksize[channel_axis]
        output_blocksize = tuple(output_blocksize)
    else:
        output_crop = crop
        output_blocksize = blocksize
    
    segmentation, output_crop_trimmed = distributed_segmentation.remove_overlaps(
        segmentation, output_crop, overlap, output_blocksize,
    )
    
    # FIX: Convert list to tuple for zarr indexing
    if isinstance(output_crop_trimmed, list):
        output_crop_trimmed = tuple(output_crop_trimmed)
    
    boxes = distributed_segmentation.bounding_boxes_in_global_coordinates(
        segmentation, output_crop_trimmed
    )
    
    # Use output shape for nblocks calculation
    shape_for_blocks = output_shape if output_shape is not None else input_zarr.shape
    nblocks = distributed_segmentation.get_nblocks(shape_for_blocks, output_blocksize)
    
    # Adjust block_index if channel axis exists
    if channel_axis is not None:
        block_index_output = list(block_index)
        del block_index_output[channel_axis]
        block_index_output = tuple(block_index_output)
    else:
        block_index_output = block_index
    
    segmentation, remap = distributed_segmentation.global_segment_ids(
        segmentation, block_index_output, nblocks
    )
    if remap[0] == 0: remap = remap[1:]

    if test_mode: return segmentation, boxes, remap
    
    output_zarr[output_crop_trimmed] = segmentation
    faces = distributed_segmentation.block_faces(segmentation)
    return faces, boxes, remap

# ========== PATCH 3: Handle multi-channel distributed_eval ==========
original_distributed_eval = distributed_segmentation.distributed_eval.__wrapped__

@distributed_segmentation.cluster
def fixed_distributed_eval(
    input_zarr,
    blocksize,
    write_path,
    mask=None,
    preprocessing_steps=[],
    model_kwargs={},
    eval_kwargs={},
    cluster=None,
    cluster_kwargs={},
    temporary_directory=None,
    channel_axis=None,
):
    """Modified to handle multi-channel 2D images"""
    import datetime
    import pathlib
    import tempfile
    import os
    import dask
    import dask.array
    import dask_jobqueue
    
    timestamp = datetime.datetime.now().strftime('%Y%m%dT%H%M%S')
    worker_logs_dirname = f'dask_worker_logs_{timestamp}'
    worker_logs_dir = pathlib.Path().absolute().joinpath(worker_logs_dirname)
    worker_logs_dir.mkdir()

    if 'diameter' not in eval_kwargs.keys():
        eval_kwargs['diameter'] = 30
    overlap = eval_kwargs['diameter'] * 2
    
    # Determine output shape (remove channel dimension if present)
    if channel_axis is not None:
        output_shape = list(input_zarr.shape)
        del output_shape[channel_axis]
        output_shape = tuple(output_shape)
        output_blocksize = list(blocksize)
        del output_blocksize[channel_axis]
        output_blocksize = tuple(output_blocksize)
    else:
        output_shape = input_zarr.shape
        output_blocksize = blocksize
    
    block_indices, block_crops = distributed_segmentation.get_block_crops(
        input_zarr.shape, blocksize, overlap, mask,
    )

    with tempfile.TemporaryDirectory(
        prefix='.', suffix='_distributed_cellpose_tempdir',
        dir=temporary_directory or os.getcwd(),
    ) as temporary_directory:

        temp_zarr_path = temporary_directory + '/segmentation_unstitched.zarr'
        temp_zarr = zarr.open(
            temp_zarr_path, 'w',
            shape=output_shape,
            chunks=output_blocksize,
            dtype=np.uint32,
        )

        futures = cluster.client.map(
            fixed_process_block,
            block_indices,
            block_crops,
            input_zarr=input_zarr,
            preprocessing_steps=preprocessing_steps,
            model_kwargs=model_kwargs,
            eval_kwargs=eval_kwargs,
            blocksize=blocksize,
            overlap=overlap,
            output_zarr=temp_zarr,
            worker_logs_directory=str(worker_logs_dir),
            channel_axis=channel_axis,
            output_shape=output_shape,
        )
        results = cluster.client.gather(futures)
        if isinstance(cluster, dask_jobqueue.core.JobQueueCluster): 
            cluster.scale(0)

        faces, boxes_, box_ids_ = list(zip(*results))
        boxes = [box for sublist in boxes_ for box in sublist]
        box_ids = np.concatenate(box_ids_).astype(int)
        new_labeling = distributed_segmentation.determine_merge_relabeling(
            block_indices, faces, box_ids
        )
        new_labeling_path = temporary_directory + '/new_labeling.npy'
        np.save(new_labeling_path, new_labeling)

        if isinstance(cluster, dask_jobqueue.core.JobQueueCluster): 
            cluster.change_worker_attributes(
                min_workers=cluster.locals_store['min_workers'],
                max_workers=cluster.locals_store['max_workers'],
                ncpus=1,
                memory="15GB",
                mem=int(15e9),
                queue=None,
                job_extra_directives=[],
            )
    
        segmentation_da = dask.array.from_zarr(temp_zarr)
        relabeled = dask.array.map_blocks(
            lambda block: np.load(new_labeling_path)[block],
            segmentation_da,
            dtype=np.uint32,
            chunks=segmentation_da.chunks,
        )
        dask.array.to_zarr(relabeled, write_path, overwrite=True)
        merged_boxes = distributed_segmentation.merge_all_boxes(
            boxes, new_labeling[box_ids]
        )
        return zarr.open(write_path, mode='r'), merged_boxes

# Apply all patches
distributed_segmentation.block_face_adjacency_graph = fixed_block_face_adjacency_graph
distributed_segmentation.distributed_eval = fixed_distributed_eval

print("✓ Patches applied successfully")
# Out:
# ✓ Patches applied successfully

# %%
three_chan = CziFile(r'E:\Steensma_Lab\OIC-222_YAP_pERK_Ki67\TMA_10272025\TMA_triplestain-1.czi')
ch1 = three_chan.read_mosaic(C=0,scale_factor=1)
ch2 = three_chan.read_mosaic(C=1,scale_factor=1)
#ch3 = three_chan.read_mosaic(C=2,scale_factor=1)

# %%
all_channels = [ch1,ch2]
all_channels = np.stack([np.squeeze(ch) for ch in all_channels],axis=0)

# %%
all_channels.shape

# %%
numpy_array_to_zarr('2Ch_test.zarr',all_channels,chunks=(2,2048,2048))

# %%
array = zarr.open('2Ch_test.zarr',mode='r')
array.shape
# Out:
# (2, 48320, 63993)

# %%
array2ch = array[:2]
array2ch.shape

# %%
model_kwargs = {
    'gpu':True,
    'pretrained_model':'cpsam',
    }
eval_kwargs = {
    'channel_axis':0,
                   }
cluster_kwargs = {
    'n_workers':1,
    'ncpus':12,
    'memory_limit':'400GB',
    'threads_per_worker':1,
                  }

# %%
segments, boxes = distributed_eval(
    input_zarr=array,
    blocksize=(array.shape[0],2048,2048),
    write_path='test_output_2chIF.zarr',
    model_kwargs=model_kwargs,
    #eval_kwargs=eval_kwargs,
    cluster_kwargs=cluster_kwargs,
    channel_axis=0,
)
# Out:
# Cluster dashboard link:  http://10.152.116.127:8787/status
# Exception in callback BaseIOStream.write.<locals>.<lambda>(<Future cancelled>) at c:\ProgramData\anaconda3\envs\cellposesamcle\lib\site-packages\tornado\iostream.py:536
# handle: <Handle BaseIOStream.write.<locals>.<lambda>(<Future cancelled>) at c:\ProgramData\anaconda3\envs\cellposesamcle\lib\site-packages\tornado\iostream.py:536>
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\envs\cellposesamcle\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\ProgramData\anaconda3\envs\cellposesamcle\lib\site-packages\tornado\iostream.py", line 536, in <lambda>
#     future.add_done_callback(lambda f: f.exception())
# asyncio.exceptions.CancelledError
# Exception in callback multi_future.<locals>.callback(<Task cancell...ession.py:77>>) at c:\ProgramData\anaconda3\envs\cellposesamcle\lib\site-packages\tornado\gen.py:526
# ...

# %%
import psutil
import os

total_ram = psutil.virtual_memory().total / (1024**3)  # GB
cpu_count = os.cpu_count()
print(f"Total RAM: {total_ram:.1f} GB")
print(f"CPU cores: {cpu_count}")

# %%
labels = zarr.open('test_output.zarr',mode='r')

# %%
viewer = napari.view_image(array,name='image')
viewer.add_labels(labels,name='labels')
